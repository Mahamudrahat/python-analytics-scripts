# %%
import pandas as pd

# %%
titanic=pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
titanic.head(1000)
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 995       3         0                               Markoff, Mr. Marin
# 996       3         0                               Markun, Mr. Johann
# 997       3         1                          Masselmani, Mrs. Fatima
# 998       3         0                             Matinoff, Mr. Nicola
# 999       3         1                McCarthy, Miss. Catherine "Katie"
#
#         sex    age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data={"Name":["Rahim","karim"],
      "Age":[23,24],
      "Salary":[4000,80000]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0  Rahim   23    4000
# 1  karim   24   80000

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic["pclass"].duplicated().sum()
# Out:
# 1306

# %%
titanic['age'].mean()
# Out:
# 29.881137667304014

# %%
import numpy as np

# %%
titanic['age']=titanic['age'].replace(np.nan,29.88)

# %%
titanic['fare'].mean()
titanic['fare']=titanic['fare'].replace(np.nan,33)

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
len(titanic[titanic['cabin'].notnull()])
# Out:
# 295

# %%
len(titanic)
# Out:
# 1309

# %%
most_frequent_cabin = titanic['cabin'].mode()[0]

# %%
most_frequent_cabin
# Out:
# 'C23 C25 C27'

# %%
# Count the occurrences of each unique value in the 'cabin' column
cabin_counts = titanic['cabin'].value_counts(dropna=False)

# Display the result
print(cabin_counts)
# Out:
# cabin
# NaN                1014
# C23 C25 C27           6
# G6                    5
# B57 B59 B63 B66       5
# C22 C26               4
#                    ...
# E63                   1
# B102                  1
# B39                   1
# D40                   1
# F38                   1
# Name: count, Length: 187, dtype: int64

# %%
titanic['cabin']=titanic['cabin'].replace(np.nan,'Unknown')

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin           0
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
most_frequent_cabin
# Out:
# 'C23 C25 C27'

# %%
titanic[titanic['cabin']=='Unknown']
# Out:
#       pclass  survived                          name     sex    age  sibsp  \
# 9          1         0       Artagaveytia, Mr. Ramon    male  71.00      0
# 13         1         1  Barber, Miss. Ellen "Nellie"  female  26.00      0
# 15         1         0           Baumann, Mr. John D    male  29.88      0
# 23         1         1         Bidois, Miss. Rosalie  female  42.00      0
# 25         1         0           Birnbaum, Mr. Jakob    male  25.00      0
# ...      ...       ...                           ...     ...    ...    ...
# 1304       3         0          Zabour, Miss. Hileni  female  14.50      1
# 1305       3         0         Zabour, Miss. Thamine  female  29.88      1
# 1306       3         0     Zakarian, Mr. Mapriededer    male  26.50      0
# 1307       3         0           Zakarian, Mr. Ortin    male  27.00      0
# 1308       3         0            Zimmerman, Mr. Leo    male  29.00      0
#
#       parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
titanic[titanic['embarked'].isnull()]
# Out:
#      pclass  survived                                       name     sex  \
# 168       1         1                        Icard, Miss. Amelie  female
# 284       1         1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       age  sibsp  parch  ticket  fare cabin embarked boat  body  \
# 168  38.0      0      0  113572  80.0   B28      NaN    6   NaN
# 284  62.0      0      0  113572  80.0   B28      NaN    6   NaN
#
#           home.dest
# 168             NaN
# 284  Cincinatti, OH

# %%
frequent_embarked=titanic['embarked'].mode()[0]
print(frequent_embarked)
# Out:
# S

# %%
# Count the occurrences of each unique value in the 'cabin' column
cabin_counts = titanic['embarked'].value_counts(dropna=False)

# Display the result
print(cabin_counts)
# Out:
# embarked
# S      914
# C      270
# Q      123
# NaN      2
# Name: count, dtype: int64

# %%
titanic['embarked'].fillna('S',inplace=True)

# %%
# Count the occurrences of each unique value in the 'cabin' column
cabin_counts = titanic['boat'].value_counts(dropna=False)

# Display the result
print(cabin_counts)
# Out:
# boat
# NaN        823
# 13          39
# C           38
# 15          37
# 14          33
# 4           31
# 10          29
# 5           27
# 3           26
# 9           25
# 11          25
# 16          23
# 8           23
# 7           23
# D           20
# 6           20
# 12          19
# 2           13
# A           11
# B            9
# 1            5
# 5 7          2
# C D          2
# 13 15        2
# 5 9          1
# 8 10         1
# 13 15 B      1
# 15 16        1
# Name: count, dtype: int64

# %%
titanic['boat']=titanic['boat'].replace(np.nan,'Unknown')

# %%
# Retrieve only the duplicate rows
titanic[titanic['boat'].notnull()]

# Display the duplicate rows
titanic[titanic[titanic['boat'].notnull()].duplicated()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
existing_body_values=set(titanic['body'].dropna().astype(int))
print(len(existing_body_values))
# Out:
# 121

# %%
def generate_unique_value():
    while True:
        random_value=np.random.randint(1,1360)
        if random_value not in existing_body_values:
            existing_body_values.add(random_value)
            return random_value
# Step 3: Replace NaN values with the generated unique values
titanic['body'] = titanic['body'].apply(lambda x: generate_unique_value() if np.isnan(x) else x)

# %%
titanic['body']
# Out:
# 0        216.0
# 1       1055.0
# 2       1301.0
# 3        135.0
# 4        549.0
#          ...
# 1304     328.0
# 1305      34.0
# 1306     304.0
# 1307    1034.0
# 1308     711.0
# Name: body, Length: 1309, dtype: float64

# %%
titanic[titanic['body'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# boat           0
# body           0
# home.dest    564
# dtype: int64

# %%
titanic['home.dest']=titanic['home.dest'].replace(np.nan,'Unknown')

# %%
titanic.head(100)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..     ...       ...                                                ...
# 95       1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# 96       1         0                         Douglas, Mr. Walter Donald
# 97       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98       1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 99       1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
#
#        sex    age  sibsp  parch    ticket      fare    cabin embarked  \
# ...

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
titanic.loc[titanic['survived'] == 1, 'survival_Status'] = 'alive'

# %%
titanic.loc[titanic['survived'] == 0, 'survival_Status'] = 'dead'

# %%
titanic.head(1309)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
titanic['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
def statusChange(pclass):
    if pclass==1:
        return 'FirstClass'
    elif pclass==2:
        return 'SecondClass'
    else:
        return 'ThirdClass'

titanic['ClassStatus']=titanic['pclass'].apply(statusChange)

# %%
print(titanic[['pclass','ClassStatus']])
# Out:
#       pclass ClassStatus
# 0          1  FirstClass
# 1          1  FirstClass
# 2          1  FirstClass
# 3          1  FirstClass
# 4          1  FirstClass
# ...      ...         ...
# 1304       3  ThirdClass
# 1305       3  ThirdClass
# 1306       3  ThirdClass
# 1307       3  ThirdClass
# 1308       3  ThirdClass
#
# [1309 rows x 2 columns]

# %%
titanic.head(1309)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
gp=titanic.groupby(['ClassStatus','sex']).agg({'sex':'count'})

# %%
print(gp)
# Out:
#                     sex
# ClassStatus sex
# FirstClass  female  144
#             male    179
# SecondClass female  106
#             male    171
# ThirdClass  female  216
#             male    493

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize': [8, 8]}, font_scale=1.2)

# %%
#Survived Rate group by 
gp=titanic[['survived','ClassStatus']].groupby(['ClassStatus'],as_index=False).mean()
print(gp)
# Out:
#    ClassStatus  survived
# 0   FirstClass  0.619195
# 1  SecondClass  0.429603
# 2   ThirdClass  0.255289

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.880909     0.498854     0.385027
# std       0.837836     0.486055    12.883193     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    22.000000     0.000000     0.000000
# 50%       3.000000     0.000000    29.880000     0.000000     0.000000
# 75%       3.000000     1.000000    35.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare         body
# count  1309.000000  1309.000000
# mean     33.295254   681.071811
# std      51.738880   393.564087
# min       0.000000     1.000000
# 25%       7.895800   336.000000
# 50%      14.454200   687.000000
# 75%      31.275000  1021.000000
# max     512.329200  1359.000000

# %%
titanic[['survived','sex']].groupby(['sex'],as_index=False).mean()
# Out:
#       sex  survived
# 0  female  0.727468
# 1    male  0.190985

# %%
titanic[['survived','sibsp']].groupby(['sibsp'],as_index=False).mean()
# Out:
#    sibsp  survived
# 0      0  0.346801
# 1      1  0.510972
# 2      2  0.452381
# 3      3  0.300000
# 4      4  0.136364
# 5      5  0.000000
# 6      8  0.000000

# %%
graph=sns.FacetGrid(titanic,col='survived')
graph.map(plt.hist, 'age',bins=20)

# %%
graph=sns.FacetGrid(titanic,col='survived',row='pclass')
graph.map(plt.hist, 'age',bins=20)

# %%
grid= sns.FacetGrid(titanic,row='embarked', col='survived',aspect=1.6)
grid.map(sns.barplot, 'sex','fare',palette='deep')
grid.add_legend()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# ...

# %%
test_titanic=pd.read_csv('https://raw.githubusercontent.com/Mahamudrahat/python-analytics-scripts/main/Datasets/test.csv')

# %%
print('befor',titanic.shape,test_titanic.shape,combine[0].shape,combine[1].shape)
# Out:
# befor (1309, 17) (418, 10) (1309, 17) (418, 10)

# %%
combine = [titanic, test_titanic]

# %%
print('befor',titanic.shape,test_titanic.shape,combine[0].shape,combine[1].shape)
# Out:
# befor (1309, 17) (418, 10) (1309, 17) (418, 10)

# %%
titanic=titanic.drop(['ticket','cabin'],axis=1)
test_titanic=test_titanic.drop(['Ticket','Cabin'],axis=1)
combine = [titanic, test_titanic]
print('After',titanic.shape,test_titanic.shape,combine[0].shape,combine[1].shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 titanic=titanic.drop(['ticket','cabin'],axis=1)
#       2 test_titanic=test_titanic.drop(['Ticket','Cabin'],axis=1)
#       3 combine = [titanic, test_titanic]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
# ...

# %%
for data in combine:
    data['Title']=  data['Title'] = titanic.name.str.extract(' ([A-Za-z]+)\.', expand=False)
pd.crosstab(titanic['Title'],titanic['sex'])
# Out:
# sex       female  male
# Title
# Capt           0     1
# Col            0     4
# Countess       1     0
# Don            0     1
# Dona           1     0
# Dr             1     7
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    61
# Miss         260     0
# Mlle           2     0
# Mme            1     0
# Mr             0   757
# Mrs          197     0
# Ms             2     0
# Rev            0     8
# Sir            0     1

# %%
combine
# Out:
# [      pclass  survived                                             name  \
#  0          1         1                    Allen, Miss. Elisabeth Walton
#  1          1         1                   Allison, Master. Hudson Trevor
#  2          1         0                     Allison, Miss. Helen Loraine
#  3          1         0             Allison, Mr. Hudson Joshua Creighton
#  4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#  ...      ...       ...                                              ...
#  1304       3         0                             Zabour, Miss. Hileni
#  1305       3         0                            Zabour, Miss. Thamine
#  1306       3         0                        Zakarian, Mr. Mapriededer
#  1307       3         0                              Zakarian, Mr. Ortin
#  1308       3         0                               Zimmerman, Mr. Leo
#
#           sex    age  sibsp  parch      fare embarked     boat    body  \
# ...

# %%
# Assuming you want to extract a specific pattern, such as the first word in the 'home.dest' column
titanic['Destination'] = titanic['home.dest'].str.extract(r'([A-Za-z]+)', expand=False)

# Display the first few rows to check the extraction
print(titanic[['home.dest', 'Destination']].head(100))
# Out:
#                            home.dest Destination
# 0                       St Louis, MO          St
# 1    Montreal, PQ / Chesterville, ON    Montreal
# 2    Montreal, PQ / Chesterville, ON    Montreal
# 3    Montreal, PQ / Chesterville, ON    Montreal
# 4    Montreal, PQ / Chesterville, ON    Montreal
# ..                               ...         ...
# 95                 San Francisco, CA         San
# 96  Deephaven, MN / Cedar Rapids, IA   Deephaven
# 97                      Montreal, PQ    Montreal
# 98  Deephaven, MN / Cedar Rapids, IA   Deephaven
# 99                    London / Paris      London
#
# [100 rows x 2 columns]

# %%
for dataset in combine:
    dataset['Title']=dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    
    dataset['Title']=dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
titanic[['Title', 'survived']].groupby(['Title'],as_index=False).mean()
# Out:
#     Title  survived
# 0  Master  0.508197
# 1    Miss  0.678030
# 2      Mr  0.162483
# 3     Mrs  0.787879
# 4    Rare  0.379310

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for data in combine:
    data['Title']=data['Title'].map(title_mapping)
    data['Title']=data['Title'].fillna(0)

# %%
titanic.head(2000)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch      fare embarked     boat    body  \
# ...

# %%
titanic['sex'].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
sex_mapping = {'male': 0, 'female': 1}

# Apply the mapping to each DataFrame in the combine list
for data in combine:
    data['sexConvNumber'] = data['sex'].map(sex_mapping)
    # Optional: Fill any NaN values if there are any  # -1 for unknown or missing values; adjust as needed

titanic.head(100)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..     ...       ...                                                ...
# 95       1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# 96       1         0                         Douglas, Mr. Walter Donald
# 97       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98       1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 99       1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
#
#        sex    age  sibsp  parch      fare embarked     boat    body  \
# ...

# %%
test_titanic = test_titanic.rename(columns={'Sex': 'sex'})

# %%
test_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         sex   Age  SibSp  Parch      Fare Embarked  Title sexConvNumber
# ...

# %%
print(titanic['sex'].unique())
# Out:
# ['female' 'male']

# %%
titanic['sexConvNumber'].value_counts()
# Out:
# sexConvNumber
# 0    843
# 1    466
# Name: count, dtype: int64
